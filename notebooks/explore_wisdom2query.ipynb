# %%
import wandb
from wisdomify.artifacts import Wisdom2QueryLoader
from wisdomify.paths import ROOT_DIR

# %%
run = wandb.init(name="explore_wisdom2query.ipynb",
                 dir=ROOT_DIR,
                 project="wisdomify",
                 entity="wisdomify")
# Out:
# wandb: Currently logged in as: wisdomify (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.12.6 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#                     Syncing run <strong><a href="https://wandb.ai/wisdomify/wisdomify/runs/82w2u6b3" target="_blank">explore_wisdom2query.ipynb</a></strong> to <a href="https://wandb.ai/wisdomify/wisdomify" target="_blank">Weights & Biases</a> (<a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">docs</a>).<br/>

# %%
loader = Wisdom2QueryLoader(run)

# %%
wisdom2query_v0 = loader("v0")

# %%
wisdom2query_v0
# Out:
# ([('소문난 잔치에 먹을 것 없다',
#    "올해 인수합병(M&A) 시장 최대어로 떠올랐던 아시아나항공이 항공시장 경쟁 심화에 따른 실적 악화와 6년째 이어지는 '알짜노선' 샌프란시스코 운항정지 소송 결과를 앞두면서 고심이 깊어지고 있다. 애초 에어부산, 에어서울 등 계열사를 한 데 묶은 '통매각' 방침도 대외적인 리스크에 힘이 빠지고 있다는 분석이다."),
#   ('갈수록 태산',
#    'LH 직원들의 신도시 예정지 땅 투기로 촉발된 부동산 불공정 사태에 이어 한 시흥시의원은 딸 명의로 신도시 발표 이전에 땅을 사고 집을 지었다.'),
#   ('꿩 대신 닭',
#    '2002년 초 LG에서 투수 생활을 접고 은퇴했던 그는 2년간 방송 해설가로 일하며 메이저리그를 깊게 파고들었다.'),
#   ('핑계 없는 무덤 없다',
#    '사람들은 마음먹은 대로, 노력한 만큼 성과가 나지 않을 경우 갖가지 구실을 대고 다른 데서 그 이유를 찾아 정당화하려고 한다.'),
#   ('갈수록 태산',
#    '오리한테 빌려준 조끼는 계속 입어보고 싶어하는 친구들-조끼를 입어봤던 친구보다 덩치가 더 큰 원숭이, 원숭이보다 더큰 물개, 물개보다 더큰 사자, 사자보다 더큰 말, 말보다 더큰 코끼리가 입어보면서 조끼는 점점 늘어나고야 만다. 마침내 줄넘기처럼 늘어져버린 조끼!'),
#   ('서당개 삼 년이면 풍월을 읊는다',
#    '하지만 지금은 인터넷 시대. 사람들이 쓰는 문장을 쏟아부어 세례를 받게 할 수 있다. 그것이 무슨 뜻이고 어떻게 번역되는지 일일이 모두 알려줄 수는 없었어도, 기계의 귀에 박히게 할 수는 있다. 우스운 비유 같지만 언어가 어떤 상황에서 어떻게 쓰이는지 그 체계가 기억되기 시작한 것이다'),
#   ('핑계 없는 무덤 없다', '형사재판을 받는 모든 피고인들에게는 나름대로 억울한 사정이 있기 마련이다.'),
#   ('서당개 삼 년이면 풍월을 읊는다',
# ...
